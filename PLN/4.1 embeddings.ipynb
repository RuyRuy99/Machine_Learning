#         3.00781250e-01, -6.17675781e-02,  3.71093750e-01, -3.78417969e-02,
#         1.37695312e-01,  3.02734375e-02,  1.25976562e-01, -1.14257812e-01,
# ...

# %%
w2vec.similarity('cat', 'lion')
# Out:
# 0.39977312

# %%
w2vec.similarity('cat', 'bat')
# Out:
# 0.2301336

# %%
w2vec.similarity('cat', 'Italy')
# Out:
# -0.04283781

# %%
w2vec.similarity('pizza', 'Italy')
# Out:
# 0.17121246

# %%
w2vec.similarity('Pasta', 'Italy')
# Out:
# 0.3146938

# %%
w2vec.similarity('pizza', 'Japan')
# Out:
# -0.029182043

# %%
w2vec.similarity('ramen', 'Japan')
# Out:
# 0.32755858

# %%
w2vec.similarity('sushi', 'Japan')
# Out:
# 0.28086233

# %%
w2vec.similarity('dog', 'China')
# Out:
# 0.04860169

# %%
w2vec.similarity('dimsum', 'China')
# Out:
# 0.28845447

# %%
w2vec.similarity('vodka', 'Russia')
# Out:
# 0.3324566

# %%
w2vec.similarity('vodka', 'Brazil')
# Out:
# 0.074208535

# %%
w2vec.similarity('carnaval', 'Brazil')
# Out:
# 0.27027178

# %%
w2vec.similarity('war', 'Iraq')
# Out:
# 0.58859944

# %%
w2vec.similarity('peace', 'Iraq')
# Out:
# 0.2329683

# %%
w2vec.similarity('hunger', 'Africa')
# Out:
# 0.26646125

# %%
w2vec.similarity('water', 'Sahara')
# Out:
# 0.13257867

# %%
w2vec.similarity('desert', 'Dubai')
# Out:
# 0.23913588

# %%
w2vec.similarity('beer', 'Deutschland')
# Out:
# 0.14590602

# %%
w2vec.similarity('data', 'Google')
# Out:
# 0.22706378

# %%
w2vec.similarity('privacy', 'Facebook')
# Out:
# 0.29442388

# %%
w2vec.similarity('house', 'apartment')
# Out:
# 0.6628996

# %%
w2vec.similarity('apartment', 'house')
# Out:
# 0.6628996

# %%
w2vec.similarity('fan', 'mouse')
# Out:
# 0.011163287

# %%
w2vec.similarity('life', 'student')
# Out:
# 0.13540104

# %%
w2vec.similarity('money', 'computer')
# Out:
# 0.18495467

# %%
w2vec.similarity('money', 'teacher')
# Out:
# 0.107133284

# %%
w2vec.similarity('money', 'professor')
# Out:
# 0.07174863

# %%
from gensim.models import KeyedVectors
w2vec_pt = KeyedVectors.load_word2vec_format('../../datasets/skip_s50.txt')

# %%
w2vec_pt['cachorro']
# Out:
# array([-0.099009, -0.130656, -0.055483, -0.115377,  0.017604, -0.320593,
#         0.129326, -0.262151,  0.202247,  0.210703,  0.270437, -0.030822,
#        -0.145418, -0.136171, -0.212965, -0.116106, -0.009094, -0.148103,
#        -0.422811,  0.225903,  0.103326,  0.52661 ,  0.096269, -0.418691,
#         0.112317, -0.314449, -0.054746,  0.447047,  0.26273 ,  0.387616,
#         0.161373, -0.240144, -0.117531, -0.092569, -0.026342,  0.060717,
#         0.193727, -0.226709, -0.613709, -0.161045,  0.415568,  0.379604,
#        -0.303765,  0.354972, -0.497266,  0.345269,  0.194365,  0.356305,
#        -0.083114, -0.108618], dtype=float32)

# %%
w2vec_pt['leão']
# Out:
# array([-0.157315,  0.171924, -0.044948,  0.254216, -0.308668, -0.17406 ,
#         0.180582, -0.069184,  0.065327, -0.269787,  0.2344  , -0.240269,
#         0.246777,  0.224258, -0.133841, -0.331898,  0.414421,  0.241198,
#        -0.485605, -0.128279, -0.299664,  0.029898,  0.092476, -0.552272,
#        -0.461127, -0.059151, -0.003775, -0.082625, -0.109592,  0.180466,
#         0.240185, -0.169356,  0.09531 ,  0.198818,  0.332006, -0.218603,
#         0.318568, -0.166894, -0.446526,  0.031041, -0.332047,  0.373337,
#         0.207225,  0.114206, -0.437114,  0.024079, -0.239283, -0.089183,
#         0.312824, -0.211004], dtype=float32)

# %%
w2vec_pt.similarity('cachorro', 'leão')
# Out:
# 0.28406787

# %%
w2vec.similarity('dog', 'lion')
# Out:
# 0.38570124

# %%
w2vec_pt.similarity('guerra', 'iraque')
# Out:
# 0.44080836

# %%
w2vec_pt.similarity('cachorro', 'china')
# Out:
# -0.13753444

# %%
w2vec_pt.similarity('carnaval', 'brasil')
# Out:
# 0.64645106

# %%
w2vec_pt.similarity('neymar', 'hexa')
# Out:
# 0.41345957

# %%
w2vec_pt.most_similar('futebol')
# Out:
# [('voleibol', 0.9184759855270386),
#  ('futsal', 0.895248293876648),
#  ('basquete', 0.8888108730316162),
#  ('handebol', 0.8857223391532898),
#  ('basquetebol', 0.8808189630508423),
#  ('sub-00', 0.8752264380455017),
#  ('rugby', 0.8588955998420715),
#  ('automobilismo', 0.8468279838562012),
#  ('vôlei', 0.8323023319244385),
#  ('rúgbi', 0.8247067928314209)]

# %%
w2vec_pt.most_similar('iraque')
# Out:
# [('iêmen', 0.9419857859611511),
#  ('irã', 0.9396375417709351),
#  ('kuwait', 0.9041733741760254),
#  ('líbano', 0.9015403389930725),
#  ('afeganistão', 0.89686518907547),
#  ('vietnã', 0.893683671951294),
#  ('iémen', 0.8721007704734802),
#  ('paquistão', 0.8709483742713928),
#  ('zaire', 0.8674913644790649),
#  ('sudão', 0.8588472604751587)]

# %%
w2vec_pt.most_similar('brasil')
# Out:
# [('méxico', 0.8149809241294861),
#  ('chile', 0.7982586622238159),
#  ('japão', 0.7834332585334778),
#  ('uruguai', 0.7684829831123352),
#  ('ceará', 0.7434583306312561),
#  ('paraguai', 0.7393295764923096),
#  ('panamá', 0.7363188862800598),
#  ('caribe', 0.7353283166885376),
#  ('país', 0.7325934171676636),
#  ('paraná', 0.7265549302101135)]

# %%
w2vec_pt.most_similar('paraíba')
# Out:
# [('bahia', 0.9185190200805664),
#  ('ceará', 0.9023164510726929),
#  ('tocantins', 0.8962117433547974),
#  ('paraná', 0.8935559988021851),
#  ('piauí', 0.8905035853385925),
#  ('pará', 0.8896589875221252),
#  ('amazonas', 0.8893381953239441),
#  ('borborema', 0.8716769814491272),
#  ('acre', 0.8375087380409241),
#  ('maranhão', 0.8361315727233887)]

# %%
w2vec_pt.most_similar('estudante')
# Out:
# [('dentista', 0.8418176770210266),
#  ('psiquiatra', 0.8407838940620422),
#  ('ginecologista', 0.8348543047904968),
#  ('pediatra', 0.8276317715644836),
#  ('ortopedista', 0.811335027217865),
#  ('obstetra', 0.8050554394721985),
#  ('anestesista', 0.8043611645698547),
#  ('psicólogo', 0.800353467464447),
#  ('oftalmologista', 0.799332320690155),
#  ('urologista', 0.7962666153907776)]

# %%
w2vec_pt.most_similar('rico')
# Out:
# [('próspero', 0.7242296934127808),
#  ('pobre', 0.6889935731887817),
#  ('afamado', 0.6871550679206848),
#  ('riquenho', 0.6828321218490601),
#  ('opulento', 0.6715371012687683),
#  ('pacato', 0.6662915945053101),
#  ('português', 0.6635689735412598),
#  ('abastado', 0.6516640782356262),
#  ('gordo', 0.6515569090843201),
#  ('riquíssimo', 0.6515045762062073)]

# %%
w2vec_pt.most_similar('câncer')
# Out:
# [('glaucoma', 0.878550112247467),
#  ('linfoma', 0.876598596572876),
#  ('cancro', 0.875778079032898),
#  ('pulmão', 0.8505293130874634),
#  ('melanoma', 0.8495396375656128),
#  ('colorretal', 0.8439008593559265),
#  ('metastático', 0.8408985137939453),
#  ('leucemia', 0.8330569267272949),
#  ('feto', 0.8314508199691772),
#  ('não-hodgkin', 0.8248034715652466)]

# %%
w2vec_pt.most_similar('computação')
# Out:
# [('computacional', 0.8649283051490784),
#  ('matemática', 0.8438237905502319),
#  ('astronomia', 0.8327099084854126),
#  ('modelagem', 0.8297738432884216),
#  ('tecnologia', 0.8230654001235962),
#  ('nanotecnologia', 0.8166918754577637),
#  ('biologia', 0.8140880465507507),
#  ('neurociência', 0.8130752444267273),
#  ('econometria', 0.810606837272644),
#  ('bioinformática', 0.8105108737945557)]

# %%
w2vec_pt.most_similar('espada')
# Out:
# [('adaga', 0.8744467496871948),
#  ('couraça', 0.8435720205307007),
#  ('tiara', 0.8415541052818298),
#  ('tyrfing', 0.8387260437011719),
#  ('armadura', 0.8355287909507751),
#  ('corôa', 0.8343896865844727),
#  ('toga', 0.8274271488189697),
#  ('serpente', 0.8171006441116333),
#  ('vestimenta', 0.8162989616394043),
#  ('maça', 0.8161488175392151)]

# %%
w2vec_pt.most_similar('índio')
# Out:
# [('matuto', 0.7599550485610962),
#  ('caboclo', 0.7544456124305725),
#  ('oxaguiam', 0.7419641017913818),
#  ('beiru', 0.7398920059204102),
#  ('evangélico', 0.7368112206459045),
#  ('cordelista', 0.7321953773498535),
#  ('mulato', 0.7317203283309937),
#  ('caprichoso', 0.7288227677345276),
#  ('curumim', 0.725116491317749),
#  ('fazendeiro', 0.7228682041168213)]

# %%
w2vec_pt.most_similar('dados')
# Out:
# [('cálculos', 0.8831533193588257),
#  ('registos', 0.8676085472106934),
#  ('parâmetros', 0.853281557559967),
#  ('metadados', 0.8390899896621704),
#  ('documentos', 0.8343610167503357),
#  ('relatórios', 0.8290340900421143),
#  ('estatísticos', 0.8286814093589783),
#  ('indicadores', 0.8184194564819336),
#  ('métodos', 0.8139909505844116),
#  ('microdados', 0.8040596842765808)]

# %%
w2vec_pt.most_similar('inteligência')
# Out:
# [('cibernética', 0.7472480535507202),
#  ('contraespionagem', 0.6952921152114868),
#  ('confiabilidade', 0.691266655921936),
#  ('tecnologia', 0.6823095679283142),
#  ('contra-espionagem', 0.6798768043518066),
#  ('nsa', 0.6788524985313416),
#  ('mídia', 0.6780558228492737),
#  ('persuasão', 0.6773074865341187),
#  ('espionagem', 0.6765494346618652),
#  ('robótica', 0.6754315495491028)]
