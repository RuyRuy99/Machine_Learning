# %%
import re

# %%
find = re.search('\\b[0-9]{5}-[0-9]{3}\\b',"meu cep é: 5833000-580")

# %%
print(find)
# Out:
# None

# %%
find2 = re.search(r'\b[0-9]{5}-[0-9]{3}\b',"meu cep é: 58330-580")

print(find2)
# Out:
# <re.Match object; span=(11, 20), match='58330-580'>

# %%
string = 'meu e-mail é : arthur@gmail.br'

# %%
found = re.search('[a-zA-Z0-9_]+@[a-zA-Z0-9\.]+\.[a-zA-Z]{2,}',string)

# %%
string[found.span()[0]:found.span()[1]]
# Out:
# 'arthur@gmail.br'

# %%
print(found)
# Out:
# <re.Match object; span=(15, 30), match='arthur@gmail.br'>
